# %%
'''Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of
Matplotlib.'''
# Out:
# 'Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of\nMatplotlib.'

# %%
'''Matplotlib is a popular data visualization library in Python. It provides a wide range of tools to create static, animated, and interactive plots in Python. Matplotlib is widely used for visualizing data in the fields of science, engineering, finance, and many others.
five plots that can be plotted using the Pyplot module of metplotlib are given below .
line plot
scatter plot
histrogram plot
bar plot
box plot'''
# Out:
# 'Matplotlib is a popular data visualization library in Python. It provides a wide range of tools to create static, animated, and interactive plots in Python. Matplotlib is widely used for visualizing data in the fields of science, engineering, finance, and many others.\nfive plots that can be plotted using the Pyplot module of metplotlib are given below .\nline plot\nscatter plot\nhistrogram plot\nbar plot\nbox plot'

# %%
'''Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
plot a scatter plot.'''
# Out:
# 'Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data\nplot a scatter plot.'

# %%
'''A scatter plot is a data visualization that displays the values of two different variables as points.'''
import matplotlib.pyplot as plt
import numpy as np
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))
plt.scatter(x,y)
plt.xlabel("this is my x axis")
plt.ylabel("this is my y axis")
plt.title("this is tittle")
plt.show()

# %%
'''Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.
Use the following data:
import numpy as np
For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])
For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])'''
# Out:
# 'Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.\nUse the following data:\nimport numpy as np\nFor line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])\nFor line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])\nFor line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])\nFor line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])'

# %%
#The subplot() function is used to create multiple plots in a single figure. It is a function provided by the Matplotlib library in Python. 
import numpy as np
import matplotlib.pyplot as plt

# Create the data for four lines
x1 = np.array([0, 1, 2, 3, 4, 5])
y1 = np.array([0, 100, 200, 300, 400, 500])

x2 = np.array([0, 1, 2, 3, 4, 5])
y2 = np.array([50, 20, 40, 20, 60, 70])

x3 = np.array([0, 1, 2, 3, 4, 5])
y3 = np.array([10, 20, 30, 40, 50, 60])

x4 = np.array([0, 1, 2, 3, 4, 5])
y4 = np.array([200, 350, 250, 550, 450, 150])

# Create a figure with four subplots
fig, axs = plt.subplots(2, 2)

# Plot the data on each subplot
axs[0, 0].plot(x1, y1)
axs[0, 1].plot(x2, y2)
axs[1, 0].plot(x3, y3)
axs[1, 1].plot(x4, y4)

# Add titles for each subplot
axs[0, 0].set_title('Line 1')
axs[0, 1].set_title('Line 2')
axs[1, 0].set_title('Line 3')
axs[1, 1].set_title('Line 4')

# Add a main title for the figure
fig.suptitle('Four line plots')

# Display the plots
plt.show()

# %%
'''Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.
import numpy as np
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])'''
# Out:
# 'Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.\nimport numpy as np\ncompany = np.array(["Apple", "Microsoft", "Google", "AMD"])\nprofit = np.array([3000, 8000, 1000, 10000])'

# %%
'''A bar plot,  is used to represent categorical data, which is data that can be divided into distinct categories. In a bar plot, each category is represented by a separate bar, and the height of the bar represents the frequency or count of data points in that category.'''
import numpy as np
import matplotlib.pyplot as plt
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])
plt.bar(company,profit)
plt.xlabel("this is company label")
plt.ylabel("this is my profit")
plt.title("this is my graph ")
plt.show()

# %%
'''Q5: What is a box plot? Why is it used? Using the following data plot a box plot.
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)'''
# Out:
# 'Q5: What is a box plot? Why is it used? Using the following data plot a box plot.\nbox1 = np.random.normal(100, 10, 200)\nbox2 = np.random.normal(90, 20, 200)'

# %%
'''A box plot, also known as a box and whisker plot, is a graphical representation of a dataset that shows the distribution of the data based on five summary statistics: minimum value, first quartile (Q1), median (Q2), third quartile (Q3), and maximum value.
Box plots are commonly used to compare the distribution of a variable across different groups or to identify potential outliers in a dataset. They are widely used in statistics, data analysis, and scientific research. '''
import numpy as np 
import matplotlib.pyplot as plt
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)
plt.boxplot([box1,box2])
p
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f239872c7f0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f2398666bf0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f239872d060>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x7f2398666c50>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f23986678e0>,
# ...
#  'means': []}
